# %% [markdown]
# # EXAMEN FINAL
# # MARIA FERNANDA MORALES ALVAREZ

# %%
import pandas as pd

# %%
data = pd.read_csv('BankChurners.csv')

# %%
from summarytools import dfSummary

# %% [markdown]
# # Resumen estadístico de los datos

# %%
data.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %% [markdown]
# # Resumen de DataFrame

# %%
dfSummary(data)
# Out:
# <style type="text/css">
# #T_80394 thead>tr>th {
#   text-align: left;
# }
# #T_80394_row0_col0, #T_80394_row1_col0, #T_80394_row2_col0, #T_80394_row3_col0, #T_80394_row4_col0, #T_80394_row5_col0, #T_80394_row6_col0, #T_80394_row7_col0, #T_80394_row8_col0, #T_80394_row9_col0, #T_80394_row10_col0, #T_80394_row11_col0, #T_80394_row12_col0, #T_80394_row13_col0, #T_80394_row14_col0, #T_80394_row15_col0, #T_80394_row16_col0, #T_80394_row17_col0, #T_80394_row18_col0, #T_80394_row19_col0, #T_80394_row20_col0, #T_80394_row21_col0, #T_80394_row22_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# ...

# %% [markdown]
# # Listado de columnas de la Data

# %%
data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %% [markdown]
# # Se carga la librería seaborn que ayuda a proporcionar una interfaz de alto nivel para crear gráficos estadísticos

# %%
import seaborn as sns

# %% [markdown]
# # Histograma que representa la distribución de las variables

# %%
sns.histplot(data = data, x='Months_on_book')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Months_on_book', ylabel='Count'>

# %%
sns.histplot(data=data, x='Total_Trans_Amt')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Total_Trans_Amt', ylabel='Count'>

# %%
sns.histplot(data=data, x='Total_Trans_Ct')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Total_Trans_Ct', ylabel='Count'>

# %% [markdown]
# # Se crea un DataFrame llamado data_clean con 3 columnas de los datos originales mostrando el contenido seleccionados

# %%
data_clean = data[['Months_on_book','Total_Trans_Amt','Total_Trans_Ct']]
data_clean
# Out:
#        Months_on_book  Total_Trans_Amt  Total_Trans_Ct
# 0                  39             1144              42
# 1                  44             1291              33
# 2                  36             1887              20
# 3                  34             1171              20
# 4                  21              816              28
# ...               ...              ...             ...
# 10122              40            15476             117
# 10123              25             8764              69
# 10124              36            10291              60
# 10125              36             8395              62
# 10126              25            10294              61
#
# [10127 rows x 3 columns]

# %% [markdown]
# # Resumen estadístico del nuevo DataFrame

# %%
data_clean.describe()
# Out:
#        Months_on_book  Total_Trans_Amt  Total_Trans_Ct
# count    10127.000000     10127.000000    10127.000000
# mean        35.928409      4404.086304       64.858695
# std          7.986416      3397.129254       23.472570
# min         13.000000       510.000000       10.000000
# 25%         31.000000      2155.500000       45.000000
# 50%         36.000000      3899.000000       67.000000
# 75%         40.000000      4741.000000       81.000000
# max         56.000000     18484.000000      139.000000

# %% [markdown]
# # Acontinuación se muestra la visualización de Datos Limpios con las 3 variables seleccionadas

# %%
data_clean
# Out:
#        Months_on_book  Total_Trans_Amt  Total_Trans_Ct
# 0                  39             1144              42
# 1                  44             1291              33
# 2                  36             1887              20
# 3                  34             1171              20
# 4                  21              816              28
# ...               ...              ...             ...
# 10122              40            15476             117
# 10123              25             8764              69
# 10124              36            10291              60
# 10125              36             8395              62
# 10126              25            10294              61
#
# [10127 rows x 3 columns]

# %% [markdown]
# # Método IQR: es una medida estadística utilizada en el análisis de datos para describir la dispersión o variación.

# %%
temp = pd.DataFrame()

for col in data_clean.columns:
    column = data_clean[col]
 
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)

    IQR = Q3 - Q1
    
    umbral_inferior = Q1 - 1.5 * IQR
    umbral_superior = Q3 + 1.5 * IQR

    data_clean[col + '_outliers'] = (column < umbral_inferior) | (column > umbral_superior)

    #temp[col + '_outliers'] = ((column < umbral_inferior) | (column > umbral_superior))

    print(f'{Q1 =} {Q3=} {IQR =} {umbral_inferior = } {umbral_superior =}')
# Out:
# Q1 =31.0 Q3=40.0 IQR =9.0 umbral_inferior = 17.5 umbral_superior =53.5
# Q1 =2155.5 Q3=4741.0 IQR =2585.5 umbral_inferior = -1722.75 umbral_superior =8619.25
# Q1 =45.0 Q3=81.0 IQR =36.0 umbral_inferior = -9.0 umbral_superior =135.0
# C:\Users\Compu Fire\AppData\Local\Temp\ipykernel_1336\178902799.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean[col + '_outliers'] = (column < umbral_inferior) | (column > umbral_superior)
# C:\Users\Compu Fire\AppData\Local\Temp\ipykernel_1336\178902799.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Visualización de data_clean posterior a realizar el método IQR para determinar en cada variables los umbrales superiores e inferiores

# %%
data_clean
# Out:
#        Months_on_book  Total_Trans_Amt  Total_Trans_Ct  \
# 0                  39             1144              42
# 1                  44             1291              33
# 2                  36             1887              20
# 3                  34             1171              20
# 4                  21              816              28
# ...               ...              ...             ...
# 10122              40            15476             117
# 10123              25             8764              69
# 10124              36            10291              60
# 10125              36             8395              62
# 10126              25            10294              61
#
#        Months_on_book_outliers  Total_Trans_Amt_outliers  \
# 0                        False                     False
# 1                        False                     False
# 2                        False                     False
# 3                        False                     False
# ...

# %% [markdown]
# # Agrupación y Conteo de Valores Atípicos en las variables. Esto proporciona información sobre la distribución de valores atípicos y no atípicos

# %%
data_clean.groupby(by='Months_on_book').count()
# Out:
#                 Total_Trans_Amt  Total_Trans_Ct  Months_on_book_outliers  \
# Months_on_book
# 13                           70              70                       70
# 14                           16              16                       16
# 15                           34              34                       34
# 16                           29              29                       29
# 17                           39              39                       39
# 18                           58              58                       58
# 19                           63              63                       63
# 20                           74              74                       74
# 21                           83              83                       83
# 22                          105             105                      105
# 23                          116             116                      116
# 24                          160             160                      160
# ...

# %%
data_clean.groupby(by='Total_Trans_Amt').count()
# Out:
#                  Months_on_book  Total_Trans_Ct  Months_on_book_outliers  \
# Total_Trans_Amt
# 510                           1               1                        1
# 530                           1               1                        1
# 563                           1               1                        1
# 569                           1               1                        1
# 594                           1               1                        1
# ...                         ...             ...                      ...
# 17628                         1               1                        1
# 17634                         1               1                        1
# 17744                         1               1                        1
# 17995                         1               1                        1
# 18484                         1               1                        1
#
#                  Total_Trans_Amt_outliers  Total_Trans_Ct_outliers
# ...

# %%
data_clean.groupby(by='Total_Trans_Ct').count()
# Out:
#                 Months_on_book  Total_Trans_Amt  Months_on_book_outliers  \
# Total_Trans_Ct
# 10                           4                4                        4
# 11                           2                2                        2
# 12                           4                4                        4
# 13                           5                5                        5
# 14                           9                9                        9
# ...                        ...              ...                      ...
# 131                          6                6                        6
# 132                          1                1                        1
# 134                          1                1                        1
# 138                          1                1                        1
# 139                          1                1                        1
#
#                 Total_Trans_Amt_outliers  Total_Trans_Ct_outliers
# ...

# %% [markdown]
# # Filtrado de Datos sin Valores Atípicos: filtra y retiene solo las observaciones que no se consideran valores atípicos en ninguna de estas tres columnas.

# %%
data_noout =  data_clean[data_clean['Months_on_book_outliers'] == False]
data_noout.reset_index(drop=True)
# Out:
#       Months_on_book  Total_Trans_Amt  Total_Trans_Ct  \
# 0                 39             1144              42
# 1                 44             1291              33
# 2                 36             1887              20
# 3                 34             1171              20
# 4                 21              816              28
# ...              ...              ...             ...
# 9736              40            15476             117
# 9737              25             8764              69
# 9738              36            10291              60
# 9739              36             8395              62
# 9740              25            10294              61
#
#       Months_on_book_outliers  Total_Trans_Amt_outliers  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                     False
# 3                       False                     False
# ...

# %% [markdown]
# # Resumen Estadístico de Datos sin Valores Atípicos

# %%
data_noout.describe()
# Out:
#        Months_on_book  Total_Trans_Amt  Total_Trans_Ct
# count     9741.000000      9741.000000     9741.000000
# mean        35.944564      4420.264963       65.066934
# std          7.070386      3390.769066       23.454667
# min         18.000000       510.000000       10.000000
# 25%         32.000000      2170.000000       45.000000
# 50%         36.000000      3921.000000       67.000000
# 75%         40.000000      4750.000000       81.000000
# max         53.000000     18484.000000      139.000000

# %% [markdown]
# # Histogramas de las variables sin Valores Atípicos. Este código utiliza Seaborn para crear un histograma que representa la distribución de las variables en el DataFrame "data_noout", que contiene datos sin valores atípicos.

# %%
sns.histplot(data=data_noout, x='Months_on_book')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Months_on_book', ylabel='Count'>

# %%
sns.histplot(data=data_noout, x='Total_Trans_Amt')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Total_Trans_Amt', ylabel='Count'>

# %%
sns.histplot(data=data_noout, x='Total_Trans_Ct')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Total_Trans_Ct', ylabel='Count'>

# %% [markdown]
# # Se importa la librería que es una técnica que se utiliza para ajustar la distribución de los datos. Ayuda a hacer que los datos sean más aproximados a una distribución normal o gaussiana

# %%
from sklearn.preprocessing import power_transform

# %% [markdown]
# # Resumen de los datos sin valores atípicos. Este resumen incluye estadísticos descriptivos e información relevante sobre las columnas

# %%
dfSummary(data_noout)
# Out:
# <style type="text/css">
# #T_ec75c thead>tr>th {
#   text-align: left;
# }
# #T_ec75c_row0_col0, #T_ec75c_row1_col0, #T_ec75c_row2_col0, #T_ec75c_row3_col0, #T_ec75c_row4_col0, #T_ec75c_row5_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_ec75c_row0_col1, #T_ec75c_row1_col1, #T_ec75c_row2_col1, #T_ec75c_row3_col1, #T_ec75c_row4_col1, #T_ec75c_row5_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_ec75c_row0_col2, #T_ec75c_row1_col2, #T_ec75c_row2_col2, #T_ec75c_row3_col2, #T_ec75c_row4_col2, #T_ec75c_row5_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_ec75c_row0_col3, #T_ec75c_row1_col3, #T_ec75c_row2_col3, #T_ec75c_row3_col3, #T_ec75c_row4_col3, #T_ec75c_row5_col3 {
#   text-align: left;
# ...

# %% [markdown]
# # Estas columnas se seleccionan para enfocar el análisis en las variables de interés específicas. Luego, el código muestra el contenido del DataFrame resultante "data_noout".

# %%
data_noout = data_noout[['Months_on_book','Total_Trans_Amt','Total_Trans_Ct']]
data_noout
# Out:
#        Months_on_book  Total_Trans_Amt  Total_Trans_Ct
# 0                  39             1144              42
# 1                  44             1291              33
# 2                  36             1887              20
# 3                  34             1171              20
# 4                  21              816              28
# ...               ...              ...             ...
# 10122              40            15476             117
# 10123              25             8764              69
# 10124              36            10291              60
# 10125              36             8395              62
# 10126              25            10294              61
#
# [9741 rows x 3 columns]

# %% [markdown]
# # La transformación de potencia se utiliza para ajustar la distribución de los datos y puede ser útil en el preprocesamiento de datos para mejorar el rendimiento de ciertos modelos o análisis estadísticos. Utiliza la función power_transformpara aplicando una transformación de potencia a los datos contenidos en el DataFrame "data_noout". Luego, crea un nuevo DataFrame llamado "data_bc" que contiene los datos transformados y muestra el contenido del DataFrame resultante "data_bc"

# %%
data_bc = power_transform(X=data_noout, method='box-cox')
data_bc = pd.DataFrame(data_bc, columns=data_noout.columns)
data_bc
# Out:
#       Months_on_book  Total_Trans_Amt  Total_Trans_Ct
# 0           0.426039        -1.823319       -0.974571
# 1           1.143267        -1.610352       -1.404892
# 2          -0.000643        -0.962552       -2.079479
# 3          -0.283449        -1.781968       -2.079479
# 4          -2.083337        -2.436221       -1.655471
# ...              ...              ...             ...
# 9736        0.568894         2.112757        2.076056
# 9737       -1.537472         1.361152        0.207917
# 9738       -0.000643         1.578989       -0.171898
# 9739       -0.000643         1.302052       -0.086426
# 9740       -1.537472         1.579380       -0.129081
#
# [9741 rows x 3 columns]

# %% [markdown]
# # Histogramas de las variables. Después de Transformación de Potencia

# %%
sns.histplot(data_bc,x= 'Months_on_book')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Months_on_book', ylabel='Count'>

# %%
sns.histplot(data_bc,x= 'Total_Trans_Amt')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Total_Trans_Amt', ylabel='Count'>

# %%
sns.histplot(data_bc,x= 'Total_Trans_Ct')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Total_Trans_Ct', ylabel='Count'>

# %% [markdown]
# # Este código utiliza Seaborn para crear los histogramas que representan las variables en el DataFrame "data_bc", que contiene datos transformados mediante la técnica de transformación de potencia (Box-Cox). Este histograma permite visualizar cómo cambia la distribución de los datos después de aplicar la transformación de potencia a las variables.

# %%
sns.histplot(data_bc,x= 'Months_on_book')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Months_on_book', ylabel='Count'>

# %%
sns.histplot(data_bc,x= 'Total_Trans_Amt')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Total_Trans_Amt', ylabel='Count'>

# %%
sns.histplot(data_bc,x= 'Total_Trans_Ct')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Total_Trans_Ct', ylabel='Count'>

# %% [markdown]
# # Resumen Estadístico de Datos Transformados (Box-Cox)". Este código utiliza la función describe()en el DataFrame "data_bc" para generar un resumen estadístico de las variables después de haber sido transformadas mediante la técnica de transformación de potencia (Box-Cox)

# %%
data_bc.describe()
# Out:
#        Months_on_book  Total_Trans_Amt  Total_Trans_Ct
# count    9.741000e+03     9.741000e+03    9.741000e+03
# mean     4.303667e-16     2.240825e-15    2.801031e-16
# std      1.000051e+00     1.000051e+00    1.000051e+00
# min     -2.487079e+00    -3.333837e+00   -2.672255e+00
# 25%     -5.648521e-01    -7.318335e-01   -8.360186e-01
# 50%     -6.431086e-04     2.007739e-01    1.245491e-01
# 75%      5.688940e-01     4.883583e-01    6.971527e-01
# max      2.451296e+00     2.336594e+00    2.869526e+00

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# # Cálculo de la Inercia para Diferentes Valores de 'k' en K-Means

# %%
inercia = []
ks = []

for k in range(1,25):
    modelo_iterado = KMeans(n_clusters = k, random_state = 5)
    modelo_iterado.fit(data_bc)
    inercia.append(modelo_iterado.inertia_)
    ks.append(k)
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# # El método del codo se utiliza para determinar el número óptimo de clusters en K-Means al analizar cómo varía la inercia con respecto a diferentes valores de 'k'. Este DataFrame se utiliza para visualizar y analizar la curva del codo para identificar un valor apropiado de 'k'.

# %%
codo = {
    'inercia': inercia,
    'k': ks
}

codo = pd.DataFrame(codo)

# %% [markdown]
# # Este código utiliza Seaborn para crear un gráfico de dispersión que muestra cómo varía la inercia en función del número de clusters 'k' y superpone una línea que conecta los puntos en el gráfico.

# %%
sns.scatterplot(data=codo,x='k',y='inercia',markers=True)
sns.lineplot(data=codo, x='k', y='inercia',)
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# # KMeans de Scikit-learn crear y entrenar un modelo K-Means con 5 clusters y una semilla aleatoria establecida en 10.

# %%
modelo = KMeans(n_clusters=5,random_state = 10)
modelo.fit(data_bc)
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=5, random_state=10)

# %% [markdown]
# #  Esta columna 'cluster' contiene las etiquetas de agrupamiento asignadas a cada observación en los datos sin valores atípicos.

# %%
data_noout['cluster'] = modelo.labels_
data_noout
# Out:
#        Months_on_book  Total_Trans_Amt  Total_Trans_Ct  cluster
# 0                  39             1144              42        1
# 1                  44             1291              33        2
# 2                  36             1887              20        1
# 3                  34             1171              20        1
# 4                  21              816              28        1
# ...               ...              ...             ...      ...
# 10122              40            15476             117        3
# 10123              25             8764              69        4
# 10124              36            10291              60        0
# 10125              36             8395              62        0
# 10126              25            10294              61        4
#
# [9741 rows x 4 columns]

# %% [markdown]
# #  Proporcionará información sobre la distribución de observaciones en los clusters creados por el modelo K-Means

# %%
data_noout.groupby(by='cluster').count()
# Out:
#          Months_on_book  Total_Trans_Amt  Total_Trans_Ct
# cluster
# 0                  3720             3720            3720
# 1                  2195             2195            2195
# 2                  1015             1015            1015
# 3                  1022             1022            1022
# 4                  1789             1789            1789

# %%
sns.scatterplot(data=data_noout,x='Total_Trans_Amt', y='Total_Trans_Ct', hue='cluster')
# Out:
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Compu Fire\anaconda3\envs\reciente\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Total_Trans_Amt', ylabel='Total_Trans_Ct'>
